# %% [markdown]
# <a href="https://colab.research.google.com/github/Hithashreee/PythonMLNLP/blob/main/mobile_price_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/ndtv_data_final.csv')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#                              Name    Brand                   Model  \
# 0  OnePlus 7T Pro McLaren Edition  OnePlus  7T Pro McLaren Edition
# 1                   Realme X2 Pro   Realme                  X2 Pro
# 2               iPhone 11 Pro Max    Apple       iPhone 11 Pro Max
# 3                       iPhone 11    Apple               iPhone 11
# 4                    LG G8X ThinQ       LG               G8X ThinQ
#
#    Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 0                    4085                  6.67         Yes          1440
# 1                    4000                  6.50         Yes          1080
# 2                    3969                  6.50         Yes          1242
# 3                    3110                  6.10         Yes           828
# 4                    4000                  6.40         Yes          1080
#
#    Resolution y  Processor  RAM (MB)  ...  Rear camera  Front camera  \
# ...

# %%
df.shape
# Out:
# (1359, 22)

# %%
df.size
# Out:
# 29898

# %%
df['Brand'].value_counts().plot(kind='pie',figsize=(15,15),autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Operating system'].value_counts().plot(kind='pie',figsize=(10,10),autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Operating system'].value_counts()
# Out:
# Operating system
# Android       1299
# Windows         19
# iOS             17
# Cyanogen        10
# BlackBerry      10
# Tizen            3
# Sailfish         1
# Name: count, dtype: int64

# %%
df['3G'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='3G'>

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
df['4G/ LTE'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='4G/ LTE'>

# %%
df['Processor'].value_counts().plot(kind='pie',figsize=(10,10),autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>
