# %% [markdown]
# <a href="https://colab.research.google.com/github/Hithashreee/PythonMLNLP/blob/main/Employee_salary_Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Employee_Salary_Dataset.csv')

# %%
df.head(3)
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000

# %%
df.tail()
# Out:
#     ID  Experience_Years  Age  Gender   Salary
# 30  31                10   34    Male    80000
# 31  32                15   54    Male   900000
# 32  33                20   55  Female  1540000
# 33  34                19   53  Female  9300000
# 34  35                16   49    Male  7600000

# %%
df.shape
# Out:
# (35, 5)

# %%
df.size
# Out:
# 175

# %%
df.columns
# Out:
# Index(['ID', 'Experience_Years', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    18
# Male      17
# Name: count, dtype: int64

# %%
df['ID'].describe()
# Out:
# count    35.000000
# mean     18.000000
# std      10.246951
# min       1.000000
# 25%       9.500000
# 50%      18.000000
# 75%      26.500000
# max      35.000000
# Name: ID, dtype: float64

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>
